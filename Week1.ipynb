# %% [markdown]
# <a href="https://colab.research.google.com/github/4rdnac/PCVK_Ganjil_2025/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://cdn.hellosehat.com/wp-content/uploads/2023/05/94a4bcb3-susu-kucinf-650x434.jpg"]
for url in urls:
    image = io.imread(url)
    image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    final_frame = cv.hconcat([image, image_2])
    cv2_imshow(final_frame)
    print("\n")
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=648x217>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi, "x",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  217 x 324
# <PIL.Image.Image image mode=RGB size=324x217>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


# membuat garis horizontal ditengah image
for y in range(lebar):
    image_3[int((tinggi)/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=648x217>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
# Jawab:
# Karena Google Colab tanpa instalasi, berbasis cloud, gratis GPU, agar memudahkan mahasiswa melakukan praktikum tanpa memerlukan laptop spek tinggi
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
#
# Jawab:
# NumPy: manipulasi array & matriks.
# pandas: kelola data tabular.
# cv2: baca & olah citra.
# skimage: pemrosesan citra lanjutan.
# PIL: resize & crop gambar.
# matplotlib: tampilkan & visualisasi citra.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak
# dilakukan?
#
# Jawab:
# untuk resize gambar jadi setengah ukuran aslinya. Jika tidak dilakukan, gambar tetap berukuran besar sehingga bisa lebih berat diproses.
#
# 4. Perhatikan potongan kode progam berikut :
# for y in range(lebar):
#     image_3[int((tinggi)/2), y] = [255, 255, 255]
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# Jawab: [255,255,255] adalah warna putih dari representasi warna putih dalam format RGB.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# Jawab:Pixel adalah elemen terkecil penyusun citra. Resolusi tinggi berarti jumlah pixel lebih banyak sehingga gambar lebih jelas. Resolusi rendah berarti pixel lebih sedikit, ganbar terlihat buram.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    image_3[x, int(lebar/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=648x217>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(lebar):
    y = int((tinggi / lebar) * x)   # hitung posisi y sesuai proporsi
    if y < tinggi:
        image_3[y, x] = [255, 255, 255]

# diagonal kiri bawah ke kanan atas
for x in range(lebar):
    y = int(tinggi - 1 - (tinggi / lebar) * x)
    if y >= 0:
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=648x217>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

panjang_garis = 100

y_tengah = tinggi // 2
x_tengah = lebar // 2

x_awal = max(0, x_tengah - panjang_garis // 2)
x_akhir = min(lebar, x_tengah + panjang_garis // 2)

for x in range(x_awal, x_akhir):
    image_3[y_tengah, x] = [255, 255, 255]


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=648x217>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

panjang = 100

y_tengah = tinggi // 2
x_tengah = lebar // 2

x_awal = max(0, x_tengah - panjang // 2)
x_akhir = min(lebar, x_tengah + panjang // 2)
y_awal = max(0, y_tengah - panjang // 2)
y_akhir = min(tinggi, y_tengah + panjang // 2)

for y in range(y_awal, y_akhir):
    for x in range(x_awal, x_akhir):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=648x217>
